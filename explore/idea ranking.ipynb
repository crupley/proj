# %% [markdown]
# # Idea Ranking: Galvanize DSI Capstone Project
#
# Ranked on the 4 componenets of an awesome project:
#
# 1. Asks a good question
# 2. Technically impressive
# 3. Obvious utility
# 4. Wrapping paper

# %%
# colnames = ['name', 'desc', 'question', 'tech', 'utility', 'wrapping']
# # feasibility, data availability, novelty, career usefulness
# data = [
#     ['lyric', 'song lyrics graph', 2, 2, 3, 5],
#     ['pylang', 'python language analysis', 3, 3, 3, 2],
#     ['photosort', 'photo library management', 4, 4, 5, 4],
#     ['pork', 'pork in bills', 4, 3, 3, 2],
#     ['simcity', 'simcity map overlays', 3, 4, 3, 5],
#     ['neighbors', 'yelp neighborhood map', 4, 4, 4, 5],
#     ['talkcode', 'plain language requests to code', 5, 4, 5, 3],
#     ['instrument', 'song musical instrument decomposition', 4, 5, 4, 4]
        
        
        
        
#     ]

# %%
#df = pd.DataFrame(data, columns=colnames)
df = pd.read_csv('idea.csv')
df
# Out:
#             name                                   desc  ?  tech  utility  \
# 0          lyric                      song lyrics graph  2     2        3
# 1         pylang               python language analysis  3     3        3
# 2      photosort               photo library management  4     4        5
# 3           pork                          pork in bills  4     3        3
# 4        simcity                   simcity map overlays  3     4        3
# 5      neighbors                  yelp neighborhood map  4     4        4
# 6       talkcode        plain language requests to code  5     4        5
# 7     instrument  song musical instrument decomposition  4     5        4
# 8         calpic         get food calories from picture  5     5        5
# 9         outfit         picture of outfit —> buy parts  5     5        5
# 10       grocery                        grocery planner  5     3        5
# 11      activity           activity recommender in city  5     3        4
# ...

# %%
df['total'] = df.iloc[:,2:].sum(axis=1)
df.sort('total', ascending=False)
# Out:
#             name                                   desc  ?  tech  utility  \
# 9         outfit         picture of outfit —> buy parts  5     5        5
# 8         calpic         get food calories from picture  5     5        5
# 6       talkcode        plain language requests to code  5     4        5
# 13  pianoteacher               custom music instruction  5     4        5
# 2      photosort               photo library management  4     4        5
# 10       grocery                        grocery planner  5     3        5
# 7     instrument  song musical instrument decomposition  4     5        4
# 14      language   language instruction, word frequency  4     4        5
# 5      neighbors                  yelp neighborhood map  4     4        4
# 4        simcity                   simcity map overlays  3     4        3
# 3           pork                          pork in bills  4     3        3
# 11      activity           activity recommender in city  5     3        4
# ...

# %% [markdown]
# ## Thoughts on top topics:
#
# 1. outfit
#     * Interesting and valuable, but the challenge of identifying individual parts of a picture is too great. **out**
# 2. calpic
#     * challenging problem
#     * scalable: picture on plain background, subset of food, etc.
#     * some labeled data available
#     * worth further investigation
# 3. talkcode
#     * incredibly valuable, incredibly difficult
#     * I'll put it in the 'maybe' pile
# 4. pianoteacher
#     * Interesting problem, will be difficult to get training data
#     * requires building app
#     * scope seems too great; **out**
# 5. photosort
#     * thumbs up
# 6. grocery
#     *
